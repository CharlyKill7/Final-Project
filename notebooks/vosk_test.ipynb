# %%
#%pip install vosk
#%pip install pyaudio

# %%
import vosk
import os
import time

# %%
# %%time

# Cargar el modelo de lenguaje en español
model = vosk.Model("models/vosk-model-es-0.42")

# Crear el reconocedor de voz
rec = vosk.KaldiRecognizer(model, 16000)
# Out:
# CPU times: total: 12.6 s
# Wall time: 30.3 s

# %%
import pyaudio

# Configurar el dispositivo de audio
audio = pyaudio.PyAudio()
stream = audio.open(format=pyaudio.paInt16,   # formato de datos de audio que se van a grabar. En este caso, se utiliza pyaudio.paInt16, que es un formato de 16 bits que se utiliza comúnmente para la grabación de voz.
                    channels=1,               # número de canales de audio que se van a grabar. En este caso, se utiliza 1, que es el número de canales para grabación mono.
                    rate=16000,               # tasa de muestreo de audio que se va a utilizar. En este caso, se utiliza 16000, que es una tasa de muestreo común para grabación de voz.
                    input=True,               # booleano que indica si el flujo de audio es de entrada o salida. En este caso, se utiliza True para indicar que se va a grabar audio desde el dispositivo.
                    frames_per_buffer=8000)   # número de cuadros de audio que se van a leer cada vez que se lee del flujo de audio. En este caso, se utiliza 8000, que es el número de cuadros que se leerán cada vez que se lee del flujo de audio.

# Definir las palabras clave
clave = "luna"
clave_stop = "tierra"

# Inicializar el reconocedor de voz
rec = vosk.KaldiRecognizer(model, 16000)

# Variables de control
grabando = False

while True:
    # Leer un fragmento de audio
    data = stream.read(4000, exception_on_overflow=False)
    # Alimentar el fragmento de audio al reconocedor de voz
    if rec.AcceptWaveform(data):
        # Obtener la transcripción
        result = rec.Result()
        if clave in result:
            grabando = True
            while grabando:
                data = stream.read(4000, exception_on_overflow=False)
                if rec.AcceptWaveform(data):
                    result2 = rec.Result()
                    if 'xt" : ""' not in result2:
                        time.sleep(0.5)
                        var = print(result2)
                        if clave_stop in result2:
                            grabando = False
# Out:
# {
#   "text" : "quiero que transcriba es todo lo que digo"
# }
# {
#   "text" : "bueno más o menos lo ha hecho bien"
# }
# {
#   "text" : "cómo te llamas"
# }
# {
#   "text" : "ahí está el tema"
# }
# {
#   "text" : "igual no necesito coger la biblioteca whisper"
# }
# {
#   "text" : "bueno"
# }
# {
#   "text" : "son sólo unos cascos"
# }
# {
#   "text" : "micro de gente"
# }
# {
#   "text" : "micro de gente de estas ahí no estás aquí estamos con sonido ambiente tú trabajas"
# }
# {
#   "text" : "el problema es la prueba concreto mundo hablando"
# }
# {
#   "text" : "pide silencio en ese momento"
# }
# {
#   "text" : "pues no funciona no hay una persona"
# }
# {
#   "text" : "las formas esto se nota mucho como cierra el sonido aquí"
# }
# {
#   "text" : "oye pero esta vez nada viable y por eso por eso lo digo"
# }
# {
#   "text" : "registro muy bien ahora tiene tiempo"
# }
# {
#   "text" : "sí y ya tengo el gel de pas ya tienes el proyecto de jugador no no qué va este es el principio bueno te queda hacer clicks más evening"
# }
# {
#   "text" : "bueno y"
# }
# {
#   "text" : "cómo coges este about en un while no es no punto final que ya tienes que salvarle una variable que puedes importar en otro archivo no no es un wild troya como llevase la autopista saliendo en tiempo real y en tiempo real te lo llevas a otro guay porque esto no deja de ser otro wild chavez en plan el chat que no lo tengo ahora"
# }
# {
#   "text" : "chávez no había pasado por allí rae quiero decir ya esta mañana estaba en el punto joder tío lo mejor es ver cómo puedes volver tengo que abrir un nuevo un nuevo frente"
# }
# {
#   "text" : "pones júpiter no búsquedas de toda esta fuga como vuelvo origen local como como sigo forzados nunca lo he sabido desde no sé que uno puedan crear atmósfera"
# }
# {
#   "text" : "cucheta plan hola vez no fue pues eso me pasa a mí cuando tiene anaconda renacimiento y ahora mismo con el actual terminal ha sido para abrir desde base la otra ciudad pero desde tal y ahí se queda"
# }
# {
#   "text" : "pero ahora veo abrir visual desde el final"
# }
# {
#   "text" : "y cuando gracias al puto proyecto está hacerlo todo con inés"
# }
# {
#   "text" : "pues he conseguido una cosa"
# }
# {
#   "text" : "open folder"
# }
# {
#   "text" : "william brown"
# }
# {
#   "text" : "siempre"
# }
# {
#   "text" : "a ver si sigue funcionando"
# }
# {
#   "text" : "jueves"
# }
# {
#   "text" : "los descuentos"
# }
# {
#   "text" : "llegó para telediario"
# }
# {
#   "text" : "la avanzaba"
# }
# {
#   "text" : "vale"
# }
# {
#   "text" : "le he venido una pequeña cosa por mapfre"
# }
# {
#   "text" : "vamos a probar esto"
# }
# {
#   "text" : "nuestras terminales"
# }
# {
#   "text" : "por"
# }
# {
#   "text" : "horario terminar new terminada"
# }
# {
#   "text" : "ves ya me habré entorno en esta web"
# }
# {
#   "text" : "piso tuviera chester"
# }
# {
#   "text" : "revolver academias ahogando su dictadura"
# }
# {
#   "text" : "pasa lo contrario reunido hoy me ha dicho ya claro que llega uno a uno"
# }
# {
#   "text" : "no cojeas todo y hacías con lucy genial papi"
# }
# {
#   "text" : "en serio"
# }
# {
#   "text" : "es que parece que no pero estando al lado de alguien descubre escogiste yo porque no podía poner las tensiones agregó clown dos y bebe y ayuda así como las unidades cineteca públicas y poder"
# }
